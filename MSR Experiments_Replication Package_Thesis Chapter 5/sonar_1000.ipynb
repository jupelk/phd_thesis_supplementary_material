# %%
import pandas as pd
df_359 = pd.read_csv('c:\\CodeBook\\new_code_rework_TD\\new_code_rework_TD\\data\\sample_main_rows_with_aggregated_data_with_jira.csv')
df_all = pd.read_csv('c:\\CodeBook\\new_code_rework_TD\\new_code_rework_TD\\data\\commits_with_jira.csv')
df_641 = df_all.loc[df_all['hash'].notna() & df_all['jira issue key'].notna()][-1000:].loc[~df_all['hash'].isin(df_359['hash'])]

# %%
# df_all.loc[df_all['hash'].notna() & df_all['hash'].isin(df_500['hash'])]
# df_all.loc[df_all['hash'].notna() & df_all['jira issue key'].notna()][-1000:].loc[~df_all['hash'].isin(df_359['hash'])]

# %%
df_641
# Out:
#                                            hash            author  \
# 15128  4b32b1420d98ea23460d05ae94f2698109b3d6f7   Wei-Chiu Chuang
# 15130  8a09bf7c19d9d2f6d6853d45e11b0d38c7c67f2a       Andrew Wang
# 15144  12d739a34ba868b3f7f5adf7f37a60d4aca9061b       Andrew Wang
# 15146  008122b3c927767ac96dc876124bc591e10c9df4     Arpit Agarwal
# 15148  dbe663d5241feea0c88a3a9391ad48a029001d94        Xiaoyu Yao
# ...                                         ...               ...
# 23843  b19d87c2b76e2fa0fc10474fefc616bd9626024d  Rajesh Balamohan
# 23846  a7fccc1122364f97c0bda86cda46978aedb66272    Hanisha Koneru
# 23852  bb1aed475b1dac1a9bf1069181016eb5b20ae55e    Steve Loughran
# 23854  17aa8f6764262767b42717cf190a53e2c1795507    Steve Loughran
# 30591  952d707240cb7dd088820d8b39e705b77fa3b6c4      Ayush Saxena
#
#                      author_date        committer             committer_date  \
# 15128  2016-10-11 13:21:33-07:00  Wei-Chiu Chuang  2016-10-11 13:21:33-07:00
# ...

# %%
df_641.loc[df_641['hash'] == 'd162252d7a7223631ff66ba0210953296407e55f']
# Out:
#                                            hash     author  \
# 18418  d162252d7a7223631ff66ba0210953296407e55f  Xiao Chen
#
#                      author_date  committer             committer_date  \
# 18418  2017-11-23 09:00:59-08:00  Xiao Chen  2017-11-23 09:01:28-08:00
#
#                                                      msg  \
# 18418  HADOOP-15067. GC time percentage reported in J...
#
#                                             parents  num_of_files  \
# 18418  ['b46ca7e73b8bac3fdbff0b13afe009308078acf2']           2.0
#
#        num_of_modified_java_files modified_java_file_name  ... added_lines  \
# 18418                         2.0                     NaN  ...         NaN
#
#       deleted_lines  nloc  file_old_path  file_new_path  jira issue key  \
# 18418           NaN   NaN            NaN            NaN    HADOOP-15067
#
#                                                  summary issue type    status  \
# ...

# %%
df_641.loc[df_641['hash'] == '4b32b1420d98ea23460d05ae94f2698109b3d6f7']
# Out:
#                                            hash           author  \
# 15128  4b32b1420d98ea23460d05ae94f2698109b3d6f7  Wei-Chiu Chuang
#
#                      author_date        committer             committer_date  \
# 15128  2016-10-11 13:21:33-07:00  Wei-Chiu Chuang  2016-10-11 13:21:33-07:00
#
#                                                      msg  \
# 15128  HADOOP-13684. Snappy may complain Hadoop is bu...
#
#                                             parents  num_of_files  \
# 15128  ['2fb392a587d288b628936ca6d18fabad04afc585']           1.0
#
#        num_of_modified_java_files modified_java_file_name  ... added_lines  \
# 15128                         1.0                     NaN  ...         NaN
#
#       deleted_lines  nloc  file_old_path  file_new_path  jira issue key  \
# 15128           NaN   NaN            NaN            NaN    HADOOP-13684
#
#                                                  summary   issue type  \
# ...
