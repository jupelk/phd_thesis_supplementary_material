# %%
import os 
response = os.popen('curl -u admin:admin_j http://localhost:9000/api/issues/search').read()

# %%
response

import json
json_data = json.loads(response)

# %%
json_data.keys()
sq_issues = json_data['issues']

sq_issues[0].keys()
# Out:
# dict_keys(['key', 'rule', 'severity', 'component', 'project', 'line', 'hash', 'textRange', 'flows', 'status', 'message', 'effort', 'debt', 'author', 'tags', 'creationDate', 'updateDate', 'type', 'scope', 'quickFixAvailable', 'messageFormattings'])

# %%
# %cd C:\GitHub_Projects\hadoop
# Out:
# C:\GitHub_Projects\hadoop

# %%
# %cd ..
# Out:
# C:\GitHub_Projects

# %%
# !git clone https://github.com/jupelk/hadoop.git
# Out:
# Cloning into 'hadoop'...
# Updating files:   3% (520/15013)
# Updating files:   4% (601/15013)
# Updating files:   5% (751/15013)
# Updating files:   6% (901/15013)
# Updating files:   7% (1051/15013)
# Updating files:   8% (1202/15013)
# Updating files:   9% (1352/15013)
# Updating files:   9% (1463/15013)
# Updating files:  10% (1502/15013)
# Updating files:  11% (1652/15013)
# Updating files:  12% (1802/15013)
# Updating files:  13% (1952/15013)
# Updating files:  13% (1956/15013)
# Updating files:  14% (2102/15013)
# Updating files:  15% (2252/15013)
# Updating files:  16% (2403/15013)
# Updating files:  17% (2553/15013)
# Updating files:  17% (2631/15013)
# Updating files:  18% (2703/15013)
# Updating files:  19% (2853/15013)
# Updating files:  20% (3003/15013)
# Updating files:  21% (3153/15013)
# Updating files:  22% (3303/15013)
# Updating files:  23% (3453/15013)
# Updating files:  23% (3470/15013)
# Updating files:  24% (3604/15013)
# Updating files:  25% (3754/15013)
# ...

# %%
# !git config core.longpaths true

# !git status
# Out:
# On branch trunk
# Your branch is up to date with 'origin/trunk'.
#
# nothing to commit, working tree clean

# %%
# %ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 0662-174A
#
#  Directory of C:\GitHub_Projects\hadoop
#
# 02/16/2023  04:46 PM    <DIR>          .
# 02/16/2023  04:35 PM    <DIR>          ..
# 02/16/2023  04:45 PM               522 .gitattributes
# 02/16/2023  04:46 PM    <DIR>          .github
# 02/16/2023  04:46 PM             2,009 .gitignore
# 02/16/2023  04:46 PM            24,283 BUILDING.txt
# 02/16/2023  04:46 PM    <DIR>          dev-support
# 02/16/2023  04:46 PM    <DIR>          hadoop-assemblies
# 02/16/2023  04:46 PM    <DIR>          hadoop-build-tools
# 02/16/2023  04:46 PM    <DIR>          hadoop-client-modules
# 02/16/2023  04:46 PM    <DIR>          hadoop-cloud-storage-project
# 02/16/2023  04:46 PM    <DIR>          hadoop-common-project
# 02/16/2023  04:46 PM    <DIR>          hadoop-dist
# 02/16/2023  04:46 PM    <DIR>          hadoop-hdfs-project
# 02/16/2023  04:46 PM    <DIR>          hadoop-mapreduce-project
# ...

# %%
# %ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 0662-174A
#
#  Directory of C:\GitHub_Projects\hadoop\hadoop-common-project
#
# 02/16/2023  04:46 PM    <DIR>          .
# 02/16/2023  04:58 PM    <DIR>          ..
# 02/16/2023  04:46 PM    <DIR>          hadoop-annotations
# 02/16/2023  04:46 PM    <DIR>          hadoop-auth
# 02/16/2023  04:46 PM    <DIR>          hadoop-auth-examples
# 02/16/2023  04:46 PM    <DIR>          hadoop-common
# 02/16/2023  04:46 PM    <DIR>          hadoop-kms
# 02/16/2023  04:46 PM    <DIR>          hadoop-minikdc
# 02/16/2023  04:46 PM    <DIR>          hadoop-nfs
# 02/16/2023  04:46 PM    <DIR>          hadoop-registry
# 02/16/2023  04:46 PM             2,071 pom.xml
#                1 File(s)          2,071 bytes
#               10 Dir(s)  13,233,897,472 bytes free

# %%
# %ls
# %cd hadoop-common-project
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 0662-174A
#
#  Directory of C:\GitHub_Projects\hadoop
#
# 02/16/2023  04:58 PM    <DIR>          .
# 02/16/2023  04:35 PM    <DIR>          ..
# 02/16/2023  04:45 PM               522 .gitattributes
# 02/16/2023  04:46 PM    <DIR>          .github
# 02/16/2023  04:46 PM             2,009 .gitignore
# 02/16/2023  04:46 PM            24,283 BUILDING.txt
# 02/16/2023  04:46 PM    <DIR>          dev-support
# 02/16/2023  04:46 PM    <DIR>          hadoop-assemblies
# 02/16/2023  04:46 PM    <DIR>          hadoop-build-tools
# 02/16/2023  04:46 PM    <DIR>          hadoop-client-modules
# 02/16/2023  04:46 PM    <DIR>          hadoop-cloud-storage-project
# 02/16/2023  04:46 PM    <DIR>          hadoop-common-project
# 02/16/2023  04:46 PM    <DIR>          hadoop-dist
# 02/16/2023  04:46 PM    <DIR>          hadoop-hdfs-project
# 02/16/2023  04:46 PM    <DIR>          hadoop-mapreduce-project
# ...

# %%
hash = '49df83899543586bbcaf80f01399ade031cf68b0'
for i in range(0, 1):
    print(i)
    # sonar-scanner -D sonar.login=sqp_0afb5debfd6c509861f92b58fea301eba2f8505f -D sonar.java.binaries=hadoop-annotations%cd hadoop-common-project
    # %cd C:\GitHub_Projects\hadoop
    # !git checkout {hash}
    # %cd hadoop-common-project
    # !sonar-scanner -D "sonar.projectKey=test_commit_analysis" -D "sonar.sources=." -D "sonar.java.binaries=."  -D "sonar.host.url=http://localhost:9000" -D "sonar.login=sqp_321c45681c2b87c2cbdb13c3de9e22e971c1b985"
    print('Done')
# Out:
# 0
# C:\GitHub_Projects\hadoop
# C:\GitHub_Projects\hadoop\hadoop-common-project
# HEAD is now at 49df838995 HADOOP-16697. Tune/audit S3A authoritative mode.
# INFO: Scanner configuration file: C:\Tools\sonar-scanner-cli-4.7.0.2747-windows\sonar-scanner-4.7.0.2747-windows\bin\..\conf\sonar-scanner.propertiesDone
#
# INFO: Project root configuration file: NONE
# INFO: SonarScanner 4.7.0.2747
# INFO: Java 11.0.14.1 Eclipse Adoptium (64-bit)
# INFO: Windows 11 10.0 amd64
# INFO: User cache: C:\Users\randi\.sonar\cache
# INFO: Scanner configuration file: C:\Tools\sonar-scanner-cli-4.7.0.2747-windows\sonar-scanner-4.7.0.2747-windows\bin\..\conf\sonar-scanner.properties
# INFO: Project root configuration file: NONE
# INFO: Analyzing on SonarQube server 9.8.0.63668
# INFO: Default locale: "en_US", source code encoding: "windows-1252" (analysis is platform dependent)
# INFO: Load global settings
# INFO: Load global settings (done) | time=186ms
# INFO: Server id: 147B411E-AYYQBmfiZX2IAd_TXxw3
# ...

# %%
# %cd ..
# Out:
# C:\GitHub_Projects\hadoop

# %%
# !git checkout
# Out:
# error: pathspec '3262495' did not match any file(s) known to git

# %%
#pick a commit hash closest to release date of release release-3.3.5-RC0

#b63b777c84556752fac40da87110729b5dfabaa7

hash = 'b63b777c84556752fac40da87110729b5dfabaa7'
for i in range(0, 1):
    print(i)
    # sonar-scanner -D sonar.login=sqp_0afb5debfd6c509861f92b58fea301eba2f8505f -D sonar.java.binaries=hadoop-annotations%cd hadoop-common-project
    # %cd C:\GitHub_Projects\hadoop
    # !git checkout {hash}
    # %cd hadoop-common-project
    # !sonar-scanner -D "sonar.projectKey=test_commit_analysis" -D "sonar.sources=." -D "sonar.java.binaries=."  -D "sonar.host.url=http://localhost:9000" -D "sonar.login=sqp_321c45681c2b87c2cbdb13c3de9e22e971c1b985"
    print('Done')

# %%
import pandas as pd
new_data_df = pd.read_csv('c:\\CodeBook\\new_code_rework_TD\\sample_main_rows_with_aggregated_data_with_jira.csv')
new_main_rows = new_data_df[new_data_df['hash'].notna()]

# %%
len(new_main_rows) * 10 / 60
# Out:
# 59.833333333333336

# %%
#pick a commit hash closest to release date of release release-3.3.4-RC0

#2c96357051718a519af7efbe748269977351fa89

# hash = '2c96357051718a519af7efbe748269977351fa89'
# for i in range(0, 1):
for i, hash in enumerate(new_main_rows['hash']):
    if i % 10 != 0:
        continue    # sonar-scanner -D sonar.login=sqp_0afb5debfd6c509861f92b58fea301eba2f8505f -D sonar.java.binaries=hadoop-annotations%cd hadoop-common-project
    # %cd C:\GitHub_Projects\hadoop
    # !git checkout {hash}
    # %cd hadoop-common-project
    # !sonar-scanner -D "sonar.projectKey=test_commit_analysis" -D "sonar.sources=." -D "sonar.projectVersion"{hash} -D "sonar.java.binaries=."  -D "sonar.host.url=http://localhost:9000" -D "sonar.login=sqp_321c45681c2b87c2cbdb13c3de9e22e971c1b985"
    print('Done')
# Out:
# C:\GitHub_Projects\hadoop
# C:\GitHub_Projects\hadoop\hadoop-common-project
# Previous HEAD position was 2c96357051 HDFS-15079. RBF: Namenode needs to use the actual client Id and callId when going through RBF proxy. (#4530)
# HEAD is now at 49df838995 HADOOP-16697. Tune/audit S3A authoritative mode.
# INFO: Scanner configuration file: C:\Tools\sonar-scanner-cli-4.7.0.2747-windows\sonar-scanner-4.7.0.2747-windows\bin\..\conf\sonar-scanner.properties
# INFO: Project root configuration file: NONE
# INFO: SonarScanner 4.7.0.2747
# INFO: Java 11.0.14.1 Eclipse Adoptium (64-bit)
# INFO: Windows 11 10.0 amd64
# INFO: User cache: C:\Users\randi\.sonar\cache
# INFO: Scanner configuration file: C:\Tools\sonar-scanner-cli-4.7.0.2747-windows\sonar-scanner-4.7.0.2747-windows\bin\..\conf\sonar-scanner.properties
# INFO: Project root configuration file: NONE
# INFO: Analyzing on SonarQube server 9.8.0.63668
# ...

# %%
import pandas as pd
new_data_df = pd.read_csv('c:\\CodeBook\\new_code_rework_TD\\sample_main_rows_with_aggregated_data_with_jira.csv')
new_main_rows = new_data_df[new_data_df['hash'].notna()]

for i, hash in enumerate(new_main_rows['hash']):
    if i % 10 != 0:
        continue    # sonar-scanner -D sonar.login=sqp_0afb5debfd6c509861f92b58fea301eba2f8505f -D sonar.java.binaries=hadoop-annotations%cd hadoop-common-project
    # %cd C:\GitHub_Projects\hadoop
    # !git checkout {hash}
    # %cd hadoop-common-project
    # !sonar-scanner -D "sonar.projectKey=hadoop_common" -D "sonar.sources=." -D "sonar.java.binaries=."  -D "sonar.host.url=http://localhost:9000" -D "sonar.login=sqp_98881dba95ad867d1d2b78d456eb589823738dce"
    
    print('Done', i, 'Hash: ', hash)
# Out:
# C:\GitHub_Projects\hadoop
# C:\GitHub_Projects\hadoop\hadoop-common-project
# Previous HEAD position was 9c887e5b82 HADOOP-18014. CallerContext should not include some characters. (#3698)
# HEAD is now at 49df838995 HADOOP-16697. Tune/audit S3A authoritative mode.
# INFO: Scanner configuration file: C:\Tools\sonar-scanner-cli-4.7.0.2747-windows\sonar-scanner-4.7.0.2747-windows\bin\..\conf\sonar-scanner.properties
# INFO: Project root configuration file: NONE
# INFO: SonarScanner 4.7.0.2747
# INFO: Java 11.0.14.1 Eclipse Adoptium (64-bit)
# INFO: Windows 11 10.0 amd64
# INFO: User cache: C:\Users\randi\.sonar\cache
# INFO: Scanner configuration file: C:\Tools\sonar-scanner-cli-4.7.0.2747-windows\sonar-scanner-4.7.0.2747-windows\bin\..\conf\sonar-scanner.properties
# INFO: Project root configuration file: NONE
# INFO: Analyzing on SonarQube server 9.8.0.63668
# INFO: Default locale: "en_US", source code encoding: "windows-1252" (analysis is platform dependent)
# ...
